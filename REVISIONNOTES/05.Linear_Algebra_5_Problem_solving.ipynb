# %% [markdown]
# ## Content
#
# - Recap
# - Problem 1
# - Problem 2
# - Problem 3
# - Problem 4
# - Problem 5

# %% [markdown]
# ## Recap

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/324/original/Screenshot_2023-09-14_at_11.17.35_AM.png?1694670474)

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/327/original/Screenshot_2023-09-14_at_11.18.22_AM.png?1694670521)

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/330/original/Screenshot_2023-09-14_at_11.19.26_AM.png?1694670961)

# %% [markdown]
# ## Problem 1
#
# suppose we have two vectors
#
# vector x =[2,1,-3]
#
# vector y=[5,8,6]
# - What is the length of the projection of x onto y?
#
#
# **Solution:**
#
# dot product: $x^t.y$ = (2)(5) + (1)(8) + (-3)(6) = 0
#
#
#  so this means in 3d space
#  - for the first vector along the x asix i have to move 2 units then 1 along y axis and -3 along z axis and similarly for the seconf vector y as well
#
#
#  now if we compute the angle here the angle will be 90 degreee, because cos theta is 0 at 90 degree
#
#  - cosθ = $\frac{x^ty}{||X||.||y||}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 2
#
# given a and b are two unit vectors such that,
#
# c=a+2b
# d=5a-4b
#
# these two are perpendicular, then what is the angle between a and b?
#
# **Solution**
# c.d will be zero because they are perpendicular
# - i.e.
# - $(a+2b).(5a-4b)=0$
# - $5||a||^2 +10a.b -4a.b - 8||b||^2$
#     - because ($a.a =||a||^2$)
# - $5.1 + 6a.b -8 =0$
#     - Because a and b are unit vectors
# - $a.b=1/2$
# - θ=60 degrees
#     - because ($a.b = ||a||.||b|| cos θ$)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Given 2 lines which are parallel to each other find the distance between them
# - $L1=w_1^T\bar{x}+w_{01}$
# - $L2=w_2^T\bar{x}+w_{02}$
#
# Where:
# - $w_1$=$[4,3]^T$
# - $w_2$=$[16,12]^T$
# - $w_{01}$=3
# - $w_{02}$=7

# %% [markdown]
# **Solution**

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/346/original/Screenshot_2023-09-14_at_12.04.26_PM.png?1694673287)

# %% [markdown]
# ## Problem 4
#
# in the classification context we have two vectors x and w Define v=x+w
#
# in which direction should we move w to reach v
# ,options are
#
# - clockwise
# - anti-clockwise

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/349/original/Screenshot_2023-09-14_at_12.18.52_PM.png?1694674147)

# %% [markdown]
# **Solution**
#
# because v will be in between these two till we use any combination by using a negative sign

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 5
#
# Suppose we have points with verly little data points and the boundry is w with $w_o = 0$,
#
# - will this be a good classifier?
# - in which direction should w rotate to make it better

# %% [markdown]
# **Solution**
#
# - no this wont be a good classsifier
#
# - we should rotate anti-clockwise, because b (misclassified point) in the positive halfspace and we need to subtract it to get there
#
#
# if a negative class is miscalssified we will do subtraction and if the positive class is miscalssified we will do addition
#
# - if point$x_i$ with lable $y_i$ is misclassified then update rule is w+ $y_ix_i$

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/057/417/original/Screenshot_2023-11-20_at_4.54.22_PM.png?1700479471)

# %% [markdown]
# Case 2 when a positive class point is misclassified
# - Here we rotate the w vector clockwise in the direction of B hence we will add the B vector to the old w vector

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/352/original/Screenshot_2023-09-14_at_12.26.03_PM.png?1694674577)
